# %%
import sys
from pathlib import Path

ROOT = Path(r"C:\____Moje-MOJE\MyProjects_4Fun\projects\World of Warcraft\python-etl")
sys.path.insert(0, str(ROOT))

# %%
from scraper_wowhead_misje import url_misji_de, scrapuj_jedna_misje

# %%
wynik = await scrapuj_jedna_misje(url_misji_de(86521))

# %%
wynik
# Out:
# {'Cele_DE': {'Główny': {1: 'Betretet Nexuspunkt Xenas und haltet Lothraxion auf.'},
#   'Podrzędny': {1: 'Bleibt ein Weilchen und hört Alleria zu',
#    2: 'Sprecht mit Alleria, um Euch in die Warteschlange für den Anhängerdungeon einzureihen',
#    3: 'Betretet Nexuspunkt Xenas und haltet Lothraxion auf',
#    4: 'Sprecht mit Decimus, um den Sturm zu schwächen',
#    5: 'Empfohlene Spielerzahl: 5'}},
#  'Treść_DE': {1: 'Wenn er den Nexuspunkt zerstört, könnten alle, für die wir kämpfen, dem Tod geweiht sein. Ich werde versuchen, ihn von seinem Plan abzubringen, doch wenn ich es nicht kann, muss ich...',
#   2: '<Allerias Miene verfinstert sich.>',
#   3: 'Wir dürfen nicht zögern. Wir müssen diese Sache beenden.'},
#  'Postęp_DE': {},
#  'Zakończenie_DE': {1: 'Es ist vorbei. Wir können aufatmen, wenn auch nur für einen Moment.'}}
