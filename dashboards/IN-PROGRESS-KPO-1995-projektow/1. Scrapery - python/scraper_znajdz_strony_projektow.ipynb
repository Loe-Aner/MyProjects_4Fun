# %%
import csv
import re
import time
from urllib.parse import urljoin, urlparse, urlunparse
import requests
from bs4 import BeautifulSoup

# %%
BASE_LIST_URL = "https://mapadotacji.gov.pl/projekty/?search-program=29425&page_no={page}" # 29425 to id krajowego programu odbudowy
BASE_SITE = "https://mapadotacji.gov.pl"
OUTPUT_CSV = "kpo_project_links.csv"

PROJECT_URL_RE = re.compile(r"^https?://mapadotacji\.gov\.pl/projekty/(\d+)/?$", re.IGNORECASE)

MAX_EMPTY_PAGES = 3 # jezeli beda 3 puste strony z rzedu, program konczy dzialanie
MAX_PAGES = 9999

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; KPO-scraper/0.2;)"
}

# %%
def normalize_absolute(href: str) -> str:
    """Normalizuje url"""
    abs_url = urljoin(BASE_SITE, href.strip())
    p = urlparse(abs_url)

    cleaned = urlunparse((p.scheme, p.netloc, p.path, "", "", ""))

    if not cleaned.endswith("/"):
        cleaned = cleaned + "/"
    return cleaned

# %%
def extract_project_links(html: str) -> list[tuple[str, str]]:
    soup = BeautifulSoup(html, "html.parser")
    results: list[tuple[str, str]] = []
    for a in soup.find_all("a", href=True):
        normalized = normalize_absolute(a["href"])
        m = PROJECT_URL_RE.match(normalized)
        if m:
            project_id = m.group(1)
            results.append((project_id, normalized))
    return results

# %%
def main():
    session = requests.Session()
    session.headers.update(HEADERS)

    seen_ids: set[str] = set()
    empty_streak = 0

    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["project_id", "url"])

        for page in range(1, MAX_PAGES + 1):
            url = BASE_LIST_URL.format(page=page)
            try:
                resp = session.get(url, timeout=20)
            except requests.RequestException as e:
                print(f"Upsi, błąd na stronie {page}: {e}")
                break

            if resp.status_code != 200:
                print(f"Strona {page}: HTTP {resp.status_code} – kończę.")
                break

            links = extract_project_links(resp.text)
            new_count = 0
            for project_id, absolute_url in links:
                if project_id not in seen_ids:
                    seen_ids.add(project_id)
                    writer.writerow([project_id, absolute_url])
                    new_count += 1

            print(f"Strona {page}: znaleziono {len(links)} linków, nowych {new_count} (razem {len(seen_ids)}).")

            if new_count == 0:
                empty_streak += 1
                if empty_streak >= MAX_EMPTY_PAGES:
                    print(f"Brak nowych linków przez {MAX_EMPTY_PAGES} strony – kończę na stronie {page}.")
                    break
            else:
                empty_streak = 0

            time.sleep(0.6)

    print(f"Gotowe! Zapisano {len(seen_ids)} unikalnych linków do pliku \"{OUTPUT_CSV}\".")

if __name__ == "__main__":
    main()
# Out:
# Strona 1: znaleziono 30 linków, nowych 10 (razem 10).
# Strona 2: znaleziono 30 linków, nowych 10 (razem 20).
# Strona 3: znaleziono 30 linków, nowych 10 (razem 30).
# Strona 4: znaleziono 30 linków, nowych 10 (razem 40).
# Strona 5: znaleziono 30 linków, nowych 10 (razem 50).
# Strona 6: znaleziono 30 linków, nowych 10 (razem 60).
# Strona 7: znaleziono 30 linków, nowych 10 (razem 70).
# Strona 8: znaleziono 30 linków, nowych 10 (razem 80).
# Strona 9: znaleziono 30 linków, nowych 10 (razem 90).
# Strona 10: znaleziono 30 linków, nowych 10 (razem 100).
# Strona 11: znaleziono 30 linków, nowych 10 (razem 110).
# Strona 12: znaleziono 30 linków, nowych 10 (razem 120).
# Strona 13: znaleziono 30 linków, nowych 10 (razem 130).
# Strona 14: znaleziono 30 linków, nowych 10 (razem 140).
# Strona 15: znaleziono 30 linków, nowych 10 (razem 150).
# Strona 16: znaleziono 30 linków, nowych 10 (razem 160).
# Strona 17: znaleziono 30 linków, nowych 10 (razem 170).
# Strona 18: znaleziono 30 linków, nowych 10 (razem 180).
# Strona 19: znaleziono 30 linków, nowych 10 (razem 190).
# Strona 20: znaleziono 30 linków, nowych 10 (razem 200).
# Strona 21: znaleziono 30 linków, nowych 10 (razem 210).
# Strona 22: znaleziono 30 linków, nowych 10 (razem 220).
# Strona 23: znaleziono 30 linków, nowych 10 (razem 230).
# Strona 24: znaleziono 30 linków, nowych 10 (razem 240).
# Strona 25: znaleziono 30 linków, nowych 10 (razem 250).
# Strona 26: znaleziono 30 linków, nowych 10 (razem 260).
# Strona 27: znaleziono 30 linków, nowych 10 (razem 270).
# Strona 28: znaleziono 30 linków, nowych 10 (razem 280).
# Strona 29: znaleziono 30 linków, nowych 10 (razem 290).
# Strona 30: znaleziono 30 linków, nowych 10 (razem 300).
# Strona 31: znaleziono 30 linków, nowych 10 (razem 310).
# Strona 32: znaleziono 30 linków, nowych 10 (razem 320).
# Strona 33: znaleziono 30 linków, nowych 10 (razem 330).
# Strona 34: znaleziono 30 linków, nowych 10 (razem 340).
# Strona 35: znaleziono 30 linków, nowych 10 (razem 350).
# Strona 36: znaleziono 30 linków, nowych 10 (razem 360).
# Strona 37: znaleziono 30 linków, nowych 10 (razem 370).
# Strona 38: znaleziono 30 linków, nowych 10 (razem 380).
# Strona 39: znaleziono 30 linków, nowych 10 (razem 390).
# Strona 40: znaleziono 30 linków, nowych 10 (razem 400).
# Strona 41: znaleziono 30 linków, nowych 10 (razem 410).
# Strona 42: znaleziono 30 linków, nowych 10 (razem 420).
# Strona 43: znaleziono 30 linków, nowych 10 (razem 430).
# Strona 44: znaleziono 30 linków, nowych 10 (razem 440).
# Strona 45: znaleziono 30 linków, nowych 10 (razem 450).
# Strona 46: znaleziono 30 linków, nowych 10 (razem 460).
# Strona 47: znaleziono 30 linków, nowych 10 (razem 470).
# Strona 48: znaleziono 30 linków, nowych 10 (razem 480).
# Strona 49: znaleziono 30 linków, nowych 10 (razem 490).
# Strona 50: znaleziono 30 linków, nowych 10 (razem 500).
# Strona 51: znaleziono 30 linków, nowych 10 (razem 510).
# Strona 52: znaleziono 30 linków, nowych 10 (razem 520).
# Strona 53: znaleziono 30 linków, nowych 10 (razem 530).
# Strona 54: znaleziono 30 linków, nowych 10 (razem 540).
# Strona 55: znaleziono 30 linków, nowych 10 (razem 550).
# Strona 56: znaleziono 30 linków, nowych 10 (razem 560).
# Strona 57: znaleziono 30 linków, nowych 10 (razem 570).
# Strona 58: znaleziono 30 linków, nowych 10 (razem 580).
# Strona 59: znaleziono 30 linków, nowych 10 (razem 590).
# Strona 60: znaleziono 30 linków, nowych 10 (razem 600).
# Strona 61: znaleziono 30 linków, nowych 10 (razem 610).
# Strona 62: znaleziono 30 linków, nowych 10 (razem 620).
# Strona 63: znaleziono 30 linków, nowych 10 (razem 630).
# Strona 64: znaleziono 30 linków, nowych 10 (razem 640).
# Strona 65: znaleziono 30 linków, nowych 10 (razem 650).
# Strona 66: znaleziono 30 linków, nowych 10 (razem 660).
# Strona 67: znaleziono 30 linków, nowych 10 (razem 670).
# Strona 68: znaleziono 30 linków, nowych 10 (razem 680).
# Strona 69: znaleziono 30 linków, nowych 10 (razem 690).
# Strona 70: znaleziono 30 linków, nowych 10 (razem 700).
# Strona 71: znaleziono 30 linków, nowych 10 (razem 710).
# Strona 72: znaleziono 30 linków, nowych 10 (razem 720).
# Strona 73: znaleziono 30 linków, nowych 10 (razem 730).
# Strona 74: znaleziono 30 linków, nowych 10 (razem 740).
# Strona 75: znaleziono 30 linków, nowych 10 (razem 750).
# Strona 76: znaleziono 30 linków, nowych 10 (razem 760).
# Strona 77: znaleziono 30 linków, nowych 10 (razem 770).
# Strona 78: znaleziono 30 linków, nowych 10 (razem 780).
# Strona 79: znaleziono 30 linków, nowych 10 (razem 790).
# Strona 80: znaleziono 30 linków, nowych 10 (razem 800).
# Strona 81: znaleziono 30 linków, nowych 10 (razem 810).
# Strona 82: znaleziono 30 linków, nowych 10 (razem 820).
# Strona 83: znaleziono 30 linków, nowych 10 (razem 830).
# Strona 84: znaleziono 30 linków, nowych 10 (razem 840).
# Strona 85: znaleziono 30 linków, nowych 10 (razem 850).
# Strona 86: znaleziono 30 linków, nowych 10 (razem 860).
# Strona 87: znaleziono 30 linków, nowych 10 (razem 870).
# Strona 88: znaleziono 30 linków, nowych 10 (razem 880).
# Strona 89: znaleziono 30 linków, nowych 10 (razem 890).
# Strona 90: znaleziono 30 linków, nowych 10 (razem 900).
# Strona 91: znaleziono 30 linków, nowych 10 (razem 910).
# Strona 92: znaleziono 30 linków, nowych 10 (razem 920).
# Strona 93: znaleziono 30 linków, nowych 10 (razem 930).
# Strona 94: znaleziono 30 linków, nowych 10 (razem 940).
# Strona 95: znaleziono 30 linków, nowych 10 (razem 950).
# Strona 96: znaleziono 30 linków, nowych 10 (razem 960).
# Strona 97: znaleziono 30 linków, nowych 10 (razem 970).
# Strona 98: znaleziono 30 linków, nowych 10 (razem 980).
# Strona 99: znaleziono 30 linków, nowych 10 (razem 990).
# Strona 100: znaleziono 30 linków, nowych 10 (razem 1000).
# Strona 101: znaleziono 30 linków, nowych 10 (razem 1010).
# Strona 102: znaleziono 30 linków, nowych 10 (razem 1020).
# Strona 103: znaleziono 30 linków, nowych 10 (razem 1030).
# Strona 104: znaleziono 30 linków, nowych 10 (razem 1040).
# Strona 105: znaleziono 30 linków, nowych 10 (razem 1050).
# Strona 106: znaleziono 30 linków, nowych 10 (razem 1060).
# Strona 107: znaleziono 30 linków, nowych 10 (razem 1070).
# Strona 108: znaleziono 30 linków, nowych 10 (razem 1080).
# Strona 109: znaleziono 30 linków, nowych 10 (razem 1090).
# Strona 110: znaleziono 30 linków, nowych 10 (razem 1100).
# Strona 111: znaleziono 30 linków, nowych 10 (razem 1110).
# Strona 112: znaleziono 30 linków, nowych 10 (razem 1120).
# Strona 113: znaleziono 30 linków, nowych 10 (razem 1130).
# Strona 114: znaleziono 30 linków, nowych 10 (razem 1140).
# Strona 115: znaleziono 30 linków, nowych 10 (razem 1150).
# Strona 116: znaleziono 30 linków, nowych 10 (razem 1160).
# Strona 117: znaleziono 30 linków, nowych 10 (razem 1170).
# Strona 118: znaleziono 30 linków, nowych 10 (razem 1180).
# Strona 119: znaleziono 30 linków, nowych 10 (razem 1190).
# Strona 120: znaleziono 30 linków, nowych 10 (razem 1200).
# Strona 121: znaleziono 30 linków, nowych 10 (razem 1210).
# Strona 122: znaleziono 30 linków, nowych 10 (razem 1220).
# Strona 123: znaleziono 30 linków, nowych 10 (razem 1230).
# Strona 124: znaleziono 30 linków, nowych 10 (razem 1240).
# Strona 125: znaleziono 30 linków, nowych 10 (razem 1250).
# Strona 126: znaleziono 30 linków, nowych 10 (razem 1260).
# Strona 127: znaleziono 30 linków, nowych 10 (razem 1270).
# Strona 128: znaleziono 30 linków, nowych 10 (razem 1280).
# Strona 129: znaleziono 30 linków, nowych 10 (razem 1290).
# Strona 130: znaleziono 30 linków, nowych 10 (razem 1300).
# Strona 131: znaleziono 30 linków, nowych 10 (razem 1310).
# Strona 132: znaleziono 30 linków, nowych 10 (razem 1320).
# Strona 133: znaleziono 30 linków, nowych 10 (razem 1330).
# Strona 134: znaleziono 30 linków, nowych 10 (razem 1340).
# Strona 135: znaleziono 30 linków, nowych 10 (razem 1350).
# Strona 136: znaleziono 30 linków, nowych 10 (razem 1360).
# Strona 137: znaleziono 30 linków, nowych 10 (razem 1370).
# Strona 138: znaleziono 30 linków, nowych 10 (razem 1380).
# Strona 139: znaleziono 30 linków, nowych 10 (razem 1390).
# Strona 140: znaleziono 30 linków, nowych 10 (razem 1400).
# Strona 141: znaleziono 30 linków, nowych 10 (razem 1410).
# Strona 142: znaleziono 30 linków, nowych 10 (razem 1420).
# Strona 143: znaleziono 30 linków, nowych 10 (razem 1430).
# Strona 144: znaleziono 30 linków, nowych 10 (razem 1440).
# Strona 145: znaleziono 30 linków, nowych 10 (razem 1450).
# Strona 146: znaleziono 30 linków, nowych 10 (razem 1460).
# Strona 147: znaleziono 30 linków, nowych 10 (razem 1470).
# Strona 148: znaleziono 30 linków, nowych 10 (razem 1480).
# Strona 149: znaleziono 30 linków, nowych 10 (razem 1490).
# Strona 150: znaleziono 30 linków, nowych 10 (razem 1500).
# Strona 151: znaleziono 30 linków, nowych 10 (razem 1510).
# Strona 152: znaleziono 30 linków, nowych 10 (razem 1520).
# Strona 153: znaleziono 30 linków, nowych 10 (razem 1530).
# Strona 154: znaleziono 30 linków, nowych 10 (razem 1540).
# Strona 155: znaleziono 30 linków, nowych 10 (razem 1550).
# Strona 156: znaleziono 30 linków, nowych 10 (razem 1560).
# Strona 157: znaleziono 30 linków, nowych 10 (razem 1570).
# Strona 158: znaleziono 30 linków, nowych 10 (razem 1580).
# Strona 159: znaleziono 30 linków, nowych 10 (razem 1590).
# Strona 160: znaleziono 30 linków, nowych 10 (razem 1600).
# Strona 161: znaleziono 30 linków, nowych 10 (razem 1610).
# Strona 162: znaleziono 30 linków, nowych 10 (razem 1620).
# Strona 163: znaleziono 30 linków, nowych 10 (razem 1630).
# Strona 164: znaleziono 30 linków, nowych 10 (razem 1640).
# Strona 165: znaleziono 30 linków, nowych 10 (razem 1650).
# Strona 166: znaleziono 30 linków, nowych 10 (razem 1660).
# Strona 167: znaleziono 30 linków, nowych 10 (razem 1670).
# Strona 168: znaleziono 30 linków, nowych 10 (razem 1680).
# Strona 169: znaleziono 30 linków, nowych 10 (razem 1690).
# Strona 170: znaleziono 30 linków, nowych 10 (razem 1700).
# Strona 171: znaleziono 30 linków, nowych 10 (razem 1710).
# Strona 172: znaleziono 30 linków, nowych 10 (razem 1720).
# Strona 173: znaleziono 30 linków, nowych 10 (razem 1730).
# Strona 174: znaleziono 30 linków, nowych 10 (razem 1740).
# Strona 175: znaleziono 30 linków, nowych 10 (razem 1750).
# Strona 176: znaleziono 30 linków, nowych 10 (razem 1760).
# Strona 177: znaleziono 30 linków, nowych 10 (razem 1770).
# Strona 178: znaleziono 30 linków, nowych 10 (razem 1780).
# Strona 179: znaleziono 30 linków, nowych 10 (razem 1790).
# Strona 180: znaleziono 30 linków, nowych 10 (razem 1800).
# Strona 181: znaleziono 30 linków, nowych 10 (razem 1810).
# Strona 182: znaleziono 30 linków, nowych 10 (razem 1820).
# Strona 183: znaleziono 30 linków, nowych 10 (razem 1830).
# Strona 184: znaleziono 30 linków, nowych 10 (razem 1840).
# Strona 185: znaleziono 30 linków, nowych 10 (razem 1850).
# Strona 186: znaleziono 30 linków, nowych 10 (razem 1860).
# Strona 187: znaleziono 30 linków, nowych 10 (razem 1870).
# Strona 188: znaleziono 30 linków, nowych 10 (razem 1880).
# Strona 189: znaleziono 30 linków, nowych 10 (razem 1890).
# Strona 190: znaleziono 30 linków, nowych 10 (razem 1900).
# Strona 191: znaleziono 30 linków, nowych 10 (razem 1910).
# Strona 192: znaleziono 30 linków, nowych 10 (razem 1920).
# Strona 193: znaleziono 30 linków, nowych 10 (razem 1930).
# Strona 194: znaleziono 30 linków, nowych 10 (razem 1940).
# Strona 195: znaleziono 30 linków, nowych 10 (razem 1950).
# Strona 196: znaleziono 30 linków, nowych 10 (razem 1960).
# Strona 197: znaleziono 30 linków, nowych 10 (razem 1970).
# Strona 198: znaleziono 30 linków, nowych 10 (razem 1980).
# Strona 199: znaleziono 45 linków, nowych 15 (razem 1995).
# Strona 200: znaleziono 15 linków, nowych 0 (razem 1995).
# Strona 201: znaleziono 0 linków, nowych 0 (razem 1995).
# Strona 202: znaleziono 0 linków, nowych 0 (razem 1995).
# Brak nowych linków przez 3 strony – kończę na stronie 202.
# Gotowe! Zapisano 1995 unikalnych linków do pliku "kpo_project_links.csv".
