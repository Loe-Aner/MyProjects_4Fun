# %% [markdown]
# Po wyczyszczeniu Molten Core z bossów wypadła lista lootu (poniżej). Twoim zadaniem jest: policzyć, ile przedmiotów wypadło dla każdej klasy zbroi, wskazać 2 najczęstsze typy, a na końcu — używając arytmetyki Counterów — sprawdzić, których typów zabrakło względem listy „wymagane przez raid". Napisz to bez ani jednego ręcznego if x in dict. Pochwal się rozwiązaniem, a ja je przejrzę okiem seniora.

# %%
from collections import Counter

# %%
loot = ["Plate", "Cloth", "Leather", "Plate", "Mail", "Cloth", "Plate", "Cloth"]
needed = Counter({"Plate": 2, "Cloth": 4, "Leather": 1, "Mail": 2})

# %%
loot_wynik = Counter(loot)
#loot_wynik
#loot_wynik.most_common(2)
needed - loot_wynik
# Out:
# Counter({'Cloth': 1, 'Mail': 1})
